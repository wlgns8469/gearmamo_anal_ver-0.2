# %%
import pandas as pd
import numpy as np
import os
from matplotlib import pyplot as plt

# %% [markdown]
# # Current 비교

# %%
path_nonmamo  = 'C:/Users/my/Desktop/mkr_gear/normal/RawData\MACHINE/Measurement/current2'
file_list = os.listdir(path_nonmamo)

# %%
dat_listn = []
for i in (file_list):
    dat = pd.read_csv(path_nonmamo+"/"+str(i), sep = '\t')
    dat_listn.append(dat)

# %%
for i in range(1,(49)):
    plt.plot(dat_listn[i].iloc[:,1])
plt.axis([0, 1500, 0, 100])
plt.show()

# %%
plt.subplot(421)
plt.axis([0, 1500, 0, 100])
plt.plot(dat_listn[0].iloc[:,1])


plt.subplot(422)
plt.axis([0, 1500, 0, 100])
plt.plot(dat_listn[0].iloc[:,1])

plt.subplot(423)
plt.axis([0, 1500, 0, 100])
plt.plot(dat_listn[0].iloc[:,1])
 
plt.subplot(424)
plt.axis([0, 1500, 0, 100])
plt.plot(dat_listn[0].iloc[:,1])


plt.subplot(425)
plt.axis([0, 1500, 0, 100])
plt.plot(dat_listn[0].iloc[:,1])


plt.subplot(426)
plt.axis([0, 1500, 0, 100])
plt.plot(dat_listn[0].iloc[:,1])

 
plt.subplot(427)
plt.axis([0, 1500, 0, 100])
plt.plot(dat_listn[0].iloc[:,1])

 
plt.subplot(428)
plt.axis([0, 1500, 0, 100])
plt.plot(dat_listn[0].iloc[:,1])


plt.show()

# %%
plt.subplot(421)
plt.axis([0, 1500, 0, 800])
plt.plot(dat_listn[0].iloc[:,1])


plt.subplot(422)
plt.axis([0, 1500, 0, 800])
plt.plot(dat_listn[0].iloc[:,1])

plt.subplot(423)
plt.axis([0, 1500, 0, 800])
plt.plot(dat_listn[0].iloc[:,1])
 
plt.subplot(424)
plt.axis([0, 1500, 0, 800])
plt.plot(dat_listn[0].iloc[:,1])


plt.subplot(425)
plt.axis([0, 1500, 0, 800])
plt.plot(dat_listn[0].iloc[:,1])


plt.subplot(426)
plt.axis([0, 1500, 0, 800])
plt.plot(dat_listn[0].iloc[:,1])

 
plt.subplot(427)
plt.axis([0, 1500, 0, 800])
plt.plot(dat_listn[0].iloc[:,1])

 
plt.subplot(428)
plt.axis([0, 1500, 0, 800])
plt.plot(dat_listn[0].iloc[:,1])


plt.show()

# %%
path_mamo  = 'C:/Users/my/Desktop/mkr_gear/abnormal/RawData\MACHINE/Measurement/current2'
file_listm = os.listdir(path_mamo)

# %%
dat_listm = []
for i in (file_listm):
    dat = pd.read_csv(path_mamo+"/"+str(i), sep ='\t')
    dat_listm.append(dat)

# %%
for i in range(1,48):
    plt.plot(dat_listm[i].iloc[:,1], )
plt.axis([0, 1500, 0, 100])
plt.show()

# %%
plt.subplot(421)
plt.axis([0, 1500, 0, 100])
plt.plot(dat_listm[0].iloc[:,1])


plt.subplot(422)
plt.axis([0, 1500, 0, 100])
plt.plot(dat_listm[0].iloc[:,1])

plt.subplot(423)
plt.axis([0, 1500, 0, 100])
plt.plot(dat_listm[0].iloc[:,1])
 
plt.subplot(424)
plt.axis([0, 1500, 0, 100])
plt.plot(dat_listm[0].iloc[:,1])


plt.subplot(425)
plt.axis([0, 1500, 0, 100])
plt.plot(dat_listm[0].iloc[:,1])


plt.subplot(426)
plt.axis([0, 1500, 0, 100])
plt.plot(dat_listm[0].iloc[:,1])

 
plt.subplot(427)
plt.axis([0, 1500, 0, 100])
plt.plot(dat_listm[0].iloc[:,1])

 
plt.subplot(428)
plt.axis([0, 1500, 0, 100])
plt.plot(dat_listm[0].iloc[:,1])


plt.show()

# %%
plt.subplot(421)
plt.axis([0, 1500, 0, 800])
plt.plot(dat_listm[0].iloc[:,1])


plt.subplot(422)
plt.axis([0, 1500, 0, 800])
plt.plot(dat_listm[0].iloc[:,1])

plt.subplot(423)
plt.axis([0, 1500, 0, 800])
plt.plot(dat_listm[0].iloc[:,1])
 
plt.subplot(424)
plt.axis([0, 1500, 0, 800])
plt.plot(dat_listm[0].iloc[:,1])


plt.subplot(425)
plt.axis([0, 1500, 0, 800])
plt.plot(dat_listm[0].iloc[:,1])


plt.subplot(426)
plt.axis([0, 1500, 0, 800])
plt.plot(dat_listm[0].iloc[:,1])

 
plt.subplot(427)
plt.axis([0, 1500, 0, 800])
plt.plot(dat_listm[0].iloc[:,1])

 
plt.subplot(428)
plt.axis([0, 1500, 0, 800])
plt.plot(dat_listm[0].iloc[:,1])


plt.show()

# %% [markdown]
# # 전류데이터의 중간값, 표준편차

# %%
for i in [1,2,3]:
    print("정상실험에서 데이터의 중간값")
    b= []
    for j in range(1,48):
        b.append(dat_listn[j].iloc[:,i].median())
    print("총 평균", np.median(b))
    print("표준편차",np.std(b))
# Out:
# 정상실험에서 데이터의 중간값
# 총 평균 63.71
# 표준편차 0.2639404795243672
# 정상실험에서 데이터의 중간값
# 총 평균 -68.16
# 표준편차 0.19850989715033476
# 정상실험에서 데이터의 중간값
# 총 평균 33.42
# 표준편차 0.31600218180335604

# %%
for i in [1,2,3]:
    print("정상실험에서 데이터의 평균값")
    b= []
    for j in range(1,48):
        b.append(dat_listn[j].iloc[:,i].mean())
    print("총 평균", np.mean(b))
    print("표준편차",np.std(b))
# Out:
# 정상실험에서 데이터의 평균값
# 총 평균 83.38081048578415
# 표준편차 5.971140454169111
# 정상실험에서 데이터의 평균값
# 총 평균 -80.2472509135438
# 표준편차 2.7999964248265097
# 정상실험에서 데이터의 평균값
# 총 평균 34.67796179786622
# 표준편차 0.2718977773883362

# %%
for i in [1,2,3]:
    print("마모실험에서 데이터의 중간값")
    a = []
    for j in range(1,48):
        a.append(dat_listm[j].iloc[:,i].median())
    print("총 평균", np.median(a))
    print("표준편차",np.std(a))
# Out:
# 마모실험에서 데이터의 중간값
# 총 평균 68.9
# 표준편차 1.0038678480784269
# 마모실험에서 데이터의 중간값
# 총 평균 -68.16
# 표준편차 0.15899931811111834
# 마모실험에서 데이터의 중간값
# 총 평균 33.42
# 표준편차 0.297735340835507

# %%
for i in [1,2,3]:
    print("마모실험에서 데이터의 평균값")
    a = []
    for j in range(1,48):
        a.append(dat_listm[j].iloc[:,i].mean())
    print("총 평균", np.mean(a))
    print("표준편차",np.std(a))
# Out:
# 마모실험에서 데이터의 평균값
# 총 평균 90.11312955080919
# 표준편차 4.581021655589427
# 마모실험에서 데이터의 평균값
# 총 평균 -78.64374710037016
# 표준편차 2.744415055602108
# 마모실험에서 데이터의 평균값
# 총 평균 34.75339332330841
# 표준편차 0.23662216616412035

# %%
path_mamo  = 'C:/Users/my/Desktop/mkr_gear/abnormal/RawData\MACHINE/Measurement/current1'
file_listm = os.listdir(path_mamo)
dat_listm = []
for i in (file_listm):
    dat = pd.read_csv(path_mamo+"/"+str(i), sep ='\t')
    dat_listm.append(dat)

# %%
for i in [1,2,3]:
    print("마모실험에서 데이터의 평균값")
    a = []
    for j in range(1,48):
        a.append(dat_listm[j].iloc[:,i].mean())
    print("총 평균", np.mean(a))
    print("표준편차",np.std(a))
# Out:
# 마모실험에서 데이터의 평균값
# 총 평균 337.7977589229976
# 표준편차 0.8870769362187662
# 마모실험에서 데이터의 평균값
# 총 평균 612.4277609334164
# 표준편차 2.036706496406726
# 마모실험에서 데이터의 평균값
# 총 평균 671.6234152197943
# 표준편차 2.6556333546367004

# %%
for i in [1,2,3]:
    print("마모실험에서 데이터의 중간값")
    a = []
    for j in range(1,48):
        a.append(dat_listm[j].iloc[:,i].median())
    print("총 평균", np.median(a))
    print("표준편차",np.std(a))
# Out:
# 마모실험에서 데이터의 중간값
# 총 평균 336.59
# 표준편차 0.9221951589940559
# 마모실험에서 데이터의 중간값
# 총 평균 613.59
# 표준편차 2.1072684631379186
# 마모실험에서 데이터의 중간값
# 총 평균 670.97
# 표준편차 2.9377645571128594

# %%
path_nonmamo  = 'C:/Users/my/Desktop/mkr_gear/normal/RawData\MACHINE/Measurement/current1'
file_list = os.listdir(path_nonmamo)
dat_listn = []
for i in (file_list):
    dat = pd.read_csv(path_nonmamo+"/"+str(i), sep = '\t')
    dat_listn.append(dat)

# %%
for i in [1,2,3]:
    print("정상실험에서 데이터의 중간값")
    b= []
    for j in range(1,48):
        b.append(dat_listn[j].iloc[:,i].median())
    print("총 평균", np.median(b))
    print("표준편차",np.std(b))
# Out:
# 정상실험에서 데이터의 중간값
# 총 평균 336.76
# 표준편차 1.4799309702742303
# 정상실험에서 데이터의 중간값
# 총 평균 611.45
# 표준편차 2.738803801895709
# 정상실험에서 데이터의 중간값
# 총 평균 666.48
# 표준편차 2.014747972673174

# %%
for i in [1,2,3]:
    print("마모실험에서 데이터의 평균값")
    a = []
    for j in range(1,48):
        a.append(dat_listn[j].iloc[:,i].mean())
    print("총 평균", np.mean(a))
    print("표준편차",np.std(a))
# Out:
# 마모실험에서 데이터의 평균값
# 총 평균 338.1801441668562
# 표준편차 1.413388168247505
# 마모실험에서 데이터의 평균값
# 총 평균 610.2479567400021
# 표준편차 2.721397830076343
# 마모실험에서 데이터의 평균값
# 총 평균 667.5120314097051
# 표준편차 1.9110119105160395

# %% [markdown]
# # joint 4 angle 비교

# %%
path_mamo  = 'C:/Users/my/Desktop/mkr_gear/abnormal/RawData\MACHINE/Measurement/position'
file_listm = os.listdir(path_mamo)

# %%
dat_listm = []
for i in (file_listm):
    dat = pd.read_csv(path_mamo+"/"+str(i), sep ='\t')
    dat_listm.append(dat)

# %%
for i in range(1,48):
    plt.plot(dat_listm[i].iloc[:,10])
plt.show()

# %%
path_nonmamo  = 'C:/Users/my/Desktop/mkr_gear/normal/RawData\MACHINE/Measurement/position'
file_list = os.listdir(path_nonmamo)

# %%
dat_listn = []
for i in (file_list):
    dat = pd.read_csv(path_nonmamo+"/"+str(i), sep = '\t')
    dat_listn.append(dat)

# %%
for i in range(1,48):
    plt.plot(dat_listn[i].iloc[:,10],)
    

plt.show()

# %% [markdown]
# # 커런트 1,2,3 비교

# %%
path_mamo  = 'C:/Users/my/Desktop/mkr_gear/abnormal/RawData\MACHINE/Measurement/current1'
file_listm = os.listdir(path_mamo)

# %%
dat_listm = []
for i in (file_listm):
    dat = pd.read_csv(path_mamo+"/"+str(i), sep ='\t')
    dat_listm.append(dat)

# %%
print("마모실험에서 데이터의 중간값")
a = 0
for i in range(1,48):
    a += dat_listm[i].iloc[:,1].median()
    print(dat_listm[i].iloc[:,1].median())
print("총 평균",a/47)
# Out:
# 마모실험에서 데이터의 중간값
# 341.7
# 339.56
# 338.57
# 337.66
# 337.01
# 337.25
# 337.17
# 336.68
# 336.27
# 336.84
# 336.51
# 336.18
# 336.35
# 336.68
# 336.51
# 336.68
# 336.51
# 336.59
# 336.68
# 336.35
# 336.51
# 336.84
# 336.35
# 336.27
# 336.54999999999995
# 336.59
# 336.84
# 336.59
# 336.68
# 336.59
# 336.76
# 336.59
# 336.59
# 337.01
# 336.27
# 336.59
# 336.59
# 336.59
# 337.01
# 336.27
# 336.59
# 336.27
# 336.84
# 336.51
# 336.27
# 336.51
# 336.27
# 총 평균 336.83170212765975

# %%
path_nonmamo  = 'C:/Users/my/Desktop/mkr_gear/normal/RawData\MACHINE/Measurement/current1'
file_list = os.listdir(path_nonmamo)

# %%
dat_listn = []
for i in (file_list):
    dat = pd.read_csv(path_nonmamo+"/"+str(i), sep = '\t')
    dat_listn.append(dat)

# %%
print("정상실험에서 데이터의 중간값")
b = 0
for i in range(1,48):
    b += dat_listn[i].iloc[:,1].median()
    print(dat_listn[i].iloc[:,1].median())

print("총 평균",b/47)
# Out:
# 정상실험에서 데이터의 중간값
# 344.5
# 341.53
# 340.38
# 338.73
# 338.815
# 338.41
# 338.08
# 337.99
# 337.53999999999996
# 336.84
# 337.17
# 337.25
# 337.25
# 337.01
# 337.01
# 337.09
# 336.76
# 337.01
# 337.17
# 336.68
# 336.72
# 337.01
# 336.76
# 336.84
# 336.54999999999995
# 336.76
# 336.27
# 336.35
# 336.27
# 336.68
# 336.59
# 336.51
# 336.68
# 336.68
# 336.84
# 336.68
# 336.76
# 336.51
# 336.59
# 337.01
# 336.51
# 335.81
# 336.68
# 337.09
# 335.69
# 336.76
# 336.59
# 총 평균 337.26393617021296

# %%
path_mamo  = 'C:/Users/my/Desktop/mkr_gear/abnormal/RawData\MACHINE/Measurement/marker'
file_listm = os.listdir(path_mamo)

# %%
dat_listm = []
for i in (file_listm):
    dat = pd.read_csv(path_mamo+"/"+str(i),sep = '\t')
    dat_listm.append(dat)

# %%
dat_listm[0][['pos_msec,tick,frame index,id,x,y,z']]
# Out:
#                     pos_msec,tick,frame index,id,x,y,z
# 0    1618408736.0,30.003549715741016,355.0,11.83193...
# 1    0.0,1618408724.2013962,1,[1],[[-1.28302693]],[...
# 2    0.0,1618408724.2013962,1,[0],[[0.98536574]],[[...
# 3    0.0,1618408724.2013962,1,[2],[[-1.54083786]],[...
# 4    42.43333333333334,1618408724.2347255,2,[1],[[-...
# ..                                                 ...
# 763  11765.266666666666,1618408735.9666708,354,[2],...
# 764  11765.266666666666,1618408735.9666708,354,[0],...
# 765  11798.6,1618408736.0,355,[1],[[-1.30009398]],[...
# 766  11798.6,1618408736.0,355,[0],[[0.95530905]],[[...
# 767  11798.6,1618408736.0,355,[2],[[-1.54408313]],[...
#
# [768 rows x 1 columns]

# %%
dat_listm[0].loc[:,:]
# Out:
#                     pos_msec,tick,frame index,id,x,y,z
# 0    1618408736.0,30.003549715741016,355.0,11.83193...
# 1    0.0,1618408724.2013962,1,[1],[[-1.28302693]],[...
# 2    0.0,1618408724.2013962,1,[0],[[0.98536574]],[[...
# 3    0.0,1618408724.2013962,1,[2],[[-1.54083786]],[...
# 4    42.43333333333334,1618408724.2347255,2,[1],[[-...
# ..                                                 ...
# 763  11765.266666666666,1618408735.9666708,354,[2],...
# 764  11765.266666666666,1618408735.9666708,354,[0],...
# 765  11798.6,1618408736.0,355,[1],[[-1.30009398]],[...
# 766  11798.6,1618408736.0,355,[0],[[0.95530905]],[[...
# 767  11798.6,1618408736.0,355,[2],[[-1.54408313]],[...
#
# [768 rows x 1 columns]

# %%
dat_listm[0]['pos_msec,tick,frame index,id,x,y,z'] = dat_listm[0]['pos_msec,tick,frame index,id,x,y,z'].astype('str')
dat_listm[0]['pos_msec,tick,frame index,id,x,y,z'] = dat_listm[0]['pos_msec,tick,frame index,id,x,y,z'].str.split(',')

# %%
dat_listm[0] = dat_listm[0].DataFrame(df.col.str.split(',', 7).tolist())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-b0c28637e9cd> in <module>
# ----> 1 dat_listm[0] = dat_listm[0].DataFrame(df.col.str.split(',', 7).tolist())
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'DataFrame'

# %%
dat_listm[1].iloc[:,0]

# %%
for i in range(1,48):
    b += dat_listn[i].iloc[:,1].median()
    print(dat_listn[i].iloc[:,1].median())
